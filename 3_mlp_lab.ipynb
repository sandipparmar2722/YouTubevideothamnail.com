# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
x=np.array([0,20])
y=np.array([0,250])

# %%
plt.plot(x,y)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
x=np.array([0,25])
y=np.array([10,350])

# %%
plt.plot(x,y)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
x=np.array([0,25])
y=np.array([0,350])

# %%
plt.plot(x,y,'o')

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
x1=np.array([2,13,25,67])
y1=np.array([10,20,85,54])
plt.plot(x1,y1)
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
x1=np.array([2,13,25,67])
y1=np.array([10,20,85,54])
c1=np.array([12,21,32,41,])
plt.plot(x1,y1,c1)
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
x1=np.array([2,13,25,67])
y1=np.array([10,20,85,54])
c1=np.array([12,21,32,41,])

# %%
plt.plot(y1,marker='o')

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
x1=np.array([2,13,25,67])
y1=np.array([10,20,85,54])
c1=np.array([12,21,32,41,])

# %%
plt.plot(y1,marker='+')

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
x1=np.array([2,13,25,67])
y1=np.array([10,20,85,54])
c1=np.array([12,21,32,41,])

# %%
plt.plot(y1,marker='*')

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
x1=np.array([2,13,25,67])
y1=np.array([10,20,85,54])

# %%
plt.plot(y1,'r')

# %%
plt.plot(y1,'d')

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
y1=np.array([10,20,85,54])
c1=np.array([12,21,32,41,])

# %%
plt.plot(y1,'r',c1,'g')

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
x1=np.array([2,13,25,67])
y1=np.array([10,20,85,54])
c1=np.array([12,21,32,41,])

# %%
plt.plot(x1,'c',y1,'r',c1,'g')

# %%
plt.plot(y1,marker='<')

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
x1=np.array([2,13,25,67])
y1=np.array([10,20,85,54])
c1=np.array([12,21,32,41,])

# %%
plt.plot(x1,y1,marker='*',ms=16,mec='c',mfc='r')

# %%
plt.plot(x1,y1,marker='<',ms=7,mec='b',mfc='g')

# %%
plt.plot(x1,y1,marker='h',ms=11,mec='g',mfc='r')

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
x1=np.array([2,13,25,67])
y1=np.array([10,20,85,54])

# %%
plt.plot(x1,y1,marker='h',ms=8,mec='b',mfc='r',ls=':')

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
x1=np.array([2,13,25])
y1=np.array([10,20,85])

# %%
plt.plot(x1,y1,linestyle='dotted',color='g',linewidth='10')

# %%
font={'color':'blue','size':'18'}
plt.title("LineChart",fontdict=font,loc="left")
plt.xlabel("number1")
plt.ylabel("number2")
#plt.show()
plt.plot(x1,y1)
plt.grid(axis='y',color='red',linestyle='--',linewidth='0.5')

# %%
plt.plot(x1,y1)
font={'color':'blue','size':'18'}
plt.title("LineChart",fontdict=font,loc="left")
plt.xlabel("number1")
plt.ylabel("number2")
plt.show()
plt.plot(x1,y1)
plt.grid(axis='y',color='red',linestyle='--',linewidth='0.5')

# %%
plt.subplot(1,2,1)
plt.title("p1")
plt.plot(x,y)
plt.subplot(1,2,2)
plt.title("p2")
plt.plot(x1,y1)
plt.suptitle("SuperTitle")
# Out:
# Text(0.5, 0.98, 'SuperTitle')

# %%
plt.subplot(2,1,1)
plt.title("p1")
plt.plot(x,y)
plt.subplot(2,1,2)
plt.title("p2")
plt.plot(x1,y1)
plt.suptitle("SuperTitle")
# Out:
# Text(0.5, 0.98, 'SuperTitle')

# %%
plt.subplot(1,2,1)
plt.title("p1")
plt.plot(x,y)
plt.subplot(1,2,2)
plt.title("p2")
plt.plot(x1,y1)
plt.suptitle("SuperTitle")
# Out:
# Text(0.5, 0.98, 'SuperTitle')
